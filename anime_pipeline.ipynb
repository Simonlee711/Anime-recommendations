# %% [markdown]
# # Anime Content Based Recommender System
# Authors: </br>
# Eugene Lee (eugenelee530@gmail.com)</br>
# Simon Lee (simonlee711@gmail.com)
#
# ```
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⡀⠀⠀⠀⢀⣀⣠⣤⣼⣿⣿⣿⣿⣿⣿⣿⣅⣀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣴⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣯⣽⣢⢤⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣿⠿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣯⡍⠲⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⠀⠀⠀⠉⠉⢩⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠋⢢⣈⠫⢄⠀⠀⠀⠀⠀⠀⢀⡄⠂⢄⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⡇⠀⠀⠀⠀⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣦⣽⣿⣿⣿⣿⣽⣿⣿⣿⣿⣷⡧⠀⠀⠀⠀⢀⠎⠀⠀⠀⢃⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣿⣿⣿⣿⣿⣿⣿⡟⠀⠀⠀⠀⣸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⣿⣟⣣⠀⠀⠀⡎⠀⠀⠀⠀⠀⡆⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣿⣿⣿⣿⣿⣿⠏⠀⠀⠀⠀⢠⣿⣿⣿⣿⣿⣿⣿⣿⡋⣿⣿⣿⣿⣿⣿⣿⣿⣿⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡔⡄⠀⠁⠀⠀⠀⠀⠀⢰⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⠿⠋⠁⠀⠀⠀⠀⠀⣼⣿⣿⣿⣿⣿⣿⣿⣿⡇⣯⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⡇⢰⠇⠀⠀⠀⠀⠀⡘⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠉⠀⠀⠀⠀⠀⠀⠀⠀⣼⣼⣿⣿⠿⣿⣿⣿⡿⢹⣿⣿⣿⣿⣿⣿⡽⣯⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠎⠦⡀⠀⠀⠀⢀⠇⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⢢⣿⡇⣼⣧⣶⣿⣿⣿⠁⢸⢿⣿⣿⣿⣿⣿⣷⡘⣷⡹⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠧⡙⠀⠑⢄⣀⠤⠂⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣸⣟⣼⣿⣿⣿⣿⣿⣿⠀⠀⢛⣿⣿⣿⣿⣿⡿⣿⡬⠿⣾⡻⣿⣿⣿⣿⣿⣿⣿⣿⣿⢯⣿⣿⣿⣿⣿⣻⡆⢰⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠂⠀⣿⢻⣿⣿⣿⣿⣿⣿⣿⡏⠉⠉⠻⢿⣿⣿⣿⣿⣜⢿⣮⡙⠷⣦⣉⠓⢿⣷⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡇⠆⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⠤⠤⠤⠤⣀⠀⠘⠀⠀⣿⢸⢿⣿⣿⣿⣿⣿⠘⢿⠈⠁⠐⠄⠙⢟⢿⣿⣿⣦⡵⣟⣶⣽⣿⣿⣿⣿⣿⣿⣿⣿⣯⣾⣿⣿⣿⣿⣼⣿⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⢀⠎⠀⠀⠀⠀⠀⠀⠑⠆⠀⠀⣿⠀⣿⣿⣿⣿⣿⣿⣀⣬⣧⣖⣢⠄⠀⠀⠀⠈⠑⠈⠹⠿⠋⠘⣿⣿⣿⡆⣿⣿⣿⡏⡧⣿⣿⣿⣿⣿⣿⣿⣧⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠊⠀⠀⠀⠀⠀⠀⠀⠀⠈⢆⠀⢿⠀⢹⣿⣿⣿⣿⣿⣿⡿⠻⣿⣿⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⢮⠴⢃⣿⣿⣿⣿⣷⡟⣿⣿⣿⣿⣿⣟⣿⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠸⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠄⠸⡆⡄⢿⣿⣿⣿⣿⣿⡻⢄⠙⢿⣻⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣾⢻⣿⣿⣿⢈⣷⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⡆⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢱⠐⠹⣵⠀⣿⣿⣿⣿⣿⢿⠦⠀⠀⠀⠀⠀⠀⠂⠀⠀⠀⠀⠀⠀⠀⡠⠞⠁⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡷⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⡁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢸⠀⠀⠘⢦⣿⣿⣿⣿⣿⣮⣆⠀⠀⠀⠀⠀⠈⠂⠀⠀⠀⠀⠀⠀⠀⠀⠀⣠⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣇⢣⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠸⠀⠀⠀⢸⣿⣿⣿⣿⣿⣿⣿⣦⣤⡤⠀⠀⠀⠀⢀⣀⣀⣀⡀⠀⠀⢀⠴⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡌⡆⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⢰⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡅⠀⠀⠀⣾⠇⣿⣿⣿⣿⣿⣿⣿⣿⣶⣄⡀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⠘⡀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡜⠀⠀⠀⣸⡟⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⣢⢄⠀⠀⢀⣤⣶⣿⢟⣿⣿⣿⣿⠰⢸⠾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡆⢡⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠰⡀⠀⠀⠀⠀⠀⠀⢀⠜⠀⠀⠀⣰⡟⠀⢸⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠇⠉⣫⢻⡿⠛⢁⢾⣿⣿⣿⡇⠇⡜⠀⡿⣻⣿⣿⣿⣿⣿⣿⣿⣿⣻⡈⡆⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠑⢄⠀⠀⠀⡠⠔⠁⠀⠀⠀⣰⡟⠀⠀⣟⣿⣿⣿⣿⣿⣿⠿⠛⠋⠉⠉⠛⠻⢗⠏⠏⢸⢇⢠⠟⣾⣿⣿⣿⣱⠊⠀⠀⡿⡞⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⢸⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠉⠈⠁⠀⠀⠀⠀⢀⡾⠋⠀⠀⣸⠇⣿⣹⣿⣿⣿⣇⠀⠀⠀⠀⠀⠀⠀⡈⠀⠀⠸⢻⠋⢸⣿⣿⣿⢿⠃⠀⠀⠀⣇⠗⢿⡇⢹⣿⣿⢿⣿⣿⣿⣿⣏⡆⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡰⠛⠁⠀⠀⢠⡟⢀⣿⣿⣿⣿⣿⡟⣄⠀⠀⠀⠀⢠⣴⣧⣤⣄⣠⠣⣀⣿⣿⣿⣟⠎⠀⠀⠀⠀⣽⠀⠘⣿⠊⠫⡺⣷⣌⠉⡿⢿⣿⡇⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡠⠊⠀⠀⠀⢀⡠⣾⣁⣼⣿⣿⣿⢹⣿⡇⠈⠑⠂⠀⠀⠈⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣽⣿⣿⠇⡜⠘⡄⠀⠹⣧⠀⠈⠪⢙⢻⠷⠦⠿⣿⡄⠀⠀
# ⠀⠀⢀⣀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡠⠊⠀⣀⠔⣒⣵⣾⣿⣿⣿⣿⣿⣿⡇⢸⣿⠀⠀⡇⠀⠀⠀⠀⣿⣿⣿⣿⠿⣿⣿⣿⣿⣿⣿⣿⣿⢋⡼⠔⠀⠉⢄⡀⠙⣧⠀⣀⡴⠉⠉⠉⠉⠹⣷⡀⠀
# ⠀⠈⢏⣷⣮⣕⠢⠀⠀⠀⠀⢠⠞⢀⠔⢉⣴⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⠁⣸⠃⠀⠠⠃⠀⠀⠀⢐⡨⠋⠀⣗⡄⢸⣿⣿⡿⡿⣿⡿⢣⠊⠀⠀⠀⠀⠀⠈⠑⠚⠻⣿⣄⣀⡀⠀⢀⣠⣿⣗⡀
# ⠀⠀⠀⢻⣿⣿⣿⣄⢂⠀⢠⣟⠔⠁⣰⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡟⢀⠏⣀⠞⠀⠀⠀⠀⠀⠈⠀⠀⠀⣿⠀⢸⣿⣟⠀⢣⠀⡰⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠈⠉⠛⠛⠛⠛⠊⢸⣿⡝
# ⠀⠀⠀⠀⢻⣿⣿⣿⣆⢃⢸⡏⢀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣾⣿⡁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠘⣧⢸⣿⡟⠀⠸⠊⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⣷
# ⠀⠀⠀⠀⠀⢻⣿⣿⣿⡞⡔⣣⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣄⠀⠀⠀⠀⠀⠀⠀⠀⣠⠀⠘⠻⡼⣇⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⡞⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣿⢻⣿
# ⠀⠀⠀⠀⠀⠀⢻⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣆⠀⠀⠀⠀⠀⠀⢀⠇⠀⠀⠀⠑⠌⠢⠀⣀⣀⠀⠀⠀⠀⠀⠀⣽⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢰⣿⢸⣿
# ⠀⠀⠀⠀⠀⠀⠈⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⡀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢀⣠⣰⣿⣿⣯⣆⠀⠀⠀⠀⠀⠃⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣼⣿⢸⣿
# ⠀⠀⠀⠀⠀⠀⠀⠈⣏⠻⢿⣿⣿⣿⣿⣿⣿⡇⠿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣷⡄⠀⠀⠆⠀⢀⣠⢰⣿⣿⣿⣿⣿⣿⣿⣿⡆⠀⠀⠀⠜⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⢠⣿⡟⢸⡟
# ⠀⠀⠀⠀⠀⠀⠀⠀⢸⢇⠈⢿⣿⣿⣿⣿⣿⠁⢀⢿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡄⡈⣠⣶⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣆⠀⢠⠁⠀⠀⠀⠀⠀⠀⠀⠀⠀⠀⣾⡟⢁⡟⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠘⠀⠆⠈⢿⣿⣿⣿⡇⠀⢸⠀⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣧⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡄⡎⠀⠀⠀⠀⠀⣀⣀⣀⣀⣀⣰⣏⣀⣊⣀⣀
# ```

# %% [markdown]
# Important libraries you will need. Most can be downloaded by simply installing latest version of Anaconda environment. You will need to pip install ```bs4``` and ```requests```
# ```
# bs4                       0.0.1                    pypi_0    pypi
# conda                     4.12.0           py39hecd8cb5_0
# conda-env                 2.6.0                         1
# mpi                       1.0                       mpich
# numpy                     1.21.5           py39h2e5f0a9_1
# pandas                    1.4.2            py39he9d5cce_0
# pip                       21.2.4           py39hecd8cb5_0
# python                    3.9.12               hdfd78df_0
# requests                  2.27.1             pyhd3eb1b0_0
# scikit-learn              1.0.2            py39hae1ba45_1
# scipy                     1.7.3            py39h8c7af03_0
# seaborn                   0.11.2             pyhd3eb1b0_0
# sympy                     1.10.1           py39hecd8cb5_0
# tqdm                      4.64.0           py39hecd8cb5_0
# ```

# %% [markdown]
# ## Step 1: Library Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from IPython.core.interactiveshell import InteractiveShell

from tqdm import tqdm
import requests
import pandas as pd
from bs4 import BeautifulSoup
import os
import sys
from pathlib import Path
import multiprocessing as mp
from multiprocessing import Process
import concurrent
from multiprocessing import Pool
import glob

InteractiveShell.ast_node_interactivity = "all"

# %%
import project_configs as project_configs

# %%
# plot parameters all coming from project.configurations
plt.style.use(project_configs.style)
plt.rcParams['font.family'] = project_configs.font_family
plt.rcParams['font.serif'] = project_configs.font_serif
plt.rcParams['font.monospace'] = project_configs.font_monospace
plt.rcParams['font.size'] = project_configs.font_size
plt.rcParams['axes.labelsize'] = project_configs.axes_label_size
plt.rcParams['axes.labelweight'] = project_configs.axes_label_weight
plt.rcParams['axes.titlesize'] = project_configs.axes_title_size
plt.rcParams['xtick.labelsize'] = project_configs.xtick_label_size
plt.rcParams['ytick.labelsize'] = project_configs.ytick_label_size
plt.rcParams['legend.fontsize'] = project_configs.legend_font_size 
plt.rcParams['figure.titlesize'] = project_configs.figure_title_size
plt.rcParams['image.cmap'] = project_configs.image_cmap 
plt.rcParams['image.interpolation'] = project_configs.image_interpolation 
plt.rcParams['figure.figsize'] = project_configs.figure_size
plt.rcParams['axes.grid']=project_configs.axes_grid
plt.rcParams['lines.linewidth'] = project_configs.lines_line_width
plt.rcParams['lines.markersize'] = project_configs.lines_marker_size
colors = ['xkcd:pale orange', 'xkcd:sea blue', 'xkcd:pale red', 'xkcd:sage green', 'xkcd:terra cotta', 'xkcd:dull purple', 'xkcd:teal', 'xkcd: goldenrod', 'xkcd:cadet blue',
'xkcd:scarlet']

# %% [markdown]
# ## Dataset
#
# We load our original datafile. Here are the current features: </br>
# ```anime_id``` - important for the next portion during our web scraping -> url + anime_id = scrape synopsis</br>
# ```name``` - name of anime</br>
# ```genre``` - genre of anime (can have multiple genres, rich quality data)</br>
# ```type``` - type of medium (TV, OVA, Movie)</br>
# ```episode``` - episode count</br>
# ```rating``` - ratings based on ?</br>
# ```members``` - useless metric. </br>
#
# ### Additional features to add
# We also want to incorperate additional features like the ```synopsis```. We intend to use a transformer architecture so having some sort of text-to-text data will improve the quality of the recommendation.

# %%
# downloaded dataset from the kaggle website
# https://www.kaggle.com/datasets/CooperUnion/anime-recommendations-database 
df = pd.read_csv("anime.csv")
df['synopsis'] = 0
df.to_csv('anime_plus.csv')
df.head(10)
# Out:
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9     15417                           Gintama&#039;: Enchousen
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports     TV       10    9.15
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 7                     Drama, Military, Sci-Fi, Space    OVA      110    9.11
# 8  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 9  Action, Comedy, Historical, Parody, Samurai, S...     TV       13    9.11
#
#    members  synopsis
# 0   200630         0
# 1   793665         0
# 2   114262         0
# 3   673572         0
# 4   151266         0
# 5    93351         0
# 6   425855         0
# 7    80679         0
# 8    72534         0
# 9    81109         0

# %%
# some useless stats
df.describe()
# Out:
#            anime_id        rating       members  synopsis
# count  12294.000000  12064.000000  1.229400e+04   12294.0
# mean   14058.221653      6.473902  1.807134e+04       0.0
# std    11455.294701      1.026746  5.482068e+04       0.0
# min        1.000000      1.670000  5.000000e+00       0.0
# 25%     3484.250000      5.880000  2.250000e+02       0.0
# 50%    10260.500000      6.570000  1.550000e+03       0.0
# 75%    24794.500000      7.180000  9.437000e+03       0.0
# max    34527.000000     10.000000  1.013917e+06       0.0

# %% [markdown]
# # Scraping the synopsis and including it in our csv
# By taking the the url: ```https://myanimelist.net/anime/``` + ```anime_id``` we are able to find the page of the current row (anime) we are looking at. And on this website we intend to scrape the subsection ```synopsis``` to be incorperated as an additional feature

# %%
class synopsis_extractor():
    '''
    A class that will scrape the summaries for us before getting written into the updated csv file
    '''
    def getdata(self, url):
        '''
        link for extract html data
        '''
        r = requests.get(url)
        return r.text

    def synopsis_scrap(self, anime_id):
        '''
        extracts the synopsis portion via keyword 'MAL' and 'Rewrite' and removes all useless crap and returns summary
        '''
        deletions = ['[Written by MAL Rewrite]', 'by MAL_Articles', '\n', '\r', '\'']
        htmldata = self.getdata("https://myanimelist.net/anime/" + anime_id)
        soup = BeautifulSoup(htmldata, 'html.parser')
        data = ''
        key = ['MAL', 'Rewrite']
        for data in soup.find_all('p'):
            summary = data.get_text()
            if [True for x in key if x in summary]:
                for i in deletions:
                    summary = summary.replace(i,'')
                return summary
            continue

# %%
# main - sample testing to show you how this works ;)

obj = synopsis_extractor()
print("Synopsis for Kimi no Na wa.")
summary = obj.synopsis_scrap('32281')
print(summary)
print("\nSynopsis for Fullmetal Alchemist: Brotherhood")
obj.synopsis_scrap('5114')
print("\nSynopsis for Gintama°")
obj.synopsis_scrap('28977')
df['synopsis'][0] = summary 
df.head(10)
# Out:
# Synopsis for Kimi no Na wa.
# Mitsuha Miyamizu, a high school girl, yearns to live the life of a boy in the bustling city of Tokyo—a dream that stands in stark contrast to her present life in the countryside. Meanwhile in the city, Taki Tachibana lives a busy life as a high school student while juggling his part-time job and hopes for a future in architecture.One day, Mitsuha awakens in a room that is not her own and suddenly finds herself living the dream life in Tokyo—but in Takis body! Elsewhere, Taki finds himself living Mitsuhas life in the humble countryside. In pursuit of an answer to this strange phenomenon, they begin to search for one another.Kimi no Na wa. revolves around Mitsuha and Takis actions, which begin to have a dramatic impact on each others lives, weaving them into a fabric held together by fate and circumstance.
#
# Synopsis for Fullmetal Alchemist: Brotherhood
# 'After a horrific alchemy experiment goes wrong in the Elric household, brothers Edward and Alphonse are left in a catastrophic new reality. Ignoring the alchemical principle banning human transmutation, the boys attempted to bring their recently deceased mother back to life. Instead, they suffered brutal personal loss: Alphonses body disintegrated while Edward lost a leg and then sacrificed an arm to keep Alphonses soul in the physical realm by binding it to a hulking suit of armor.The brothers are rescued by their neighbor Pinako Rockbell and her granddaughter Winry. Known as a bio-mechanical engineering prodigy, Winry creates prosthetic limbs for Edward by utilizing "automail," a tough, versatile metal used in robots and combat armor. After years of training, the Elric brothers set off on a quest to restore their bodies by locating the Philosophers Stone—a powerful gem that allows an alchemist to defy the traditional laws of Equivalent Exchange.As Edward becomes an infamous alchemist and gains the nickname "Fullmetal," the boys journey embroils them in a growing conspiracy that threatens the fate of the world.'
# Synopsis for Gintama°
# 'Gintoki, Shinpachi, and Kagura return as the fun-loving but broke members of the Yorozuya team! Living in an alternate-reality Edo, where swords are prohibited and alien overlords have conquered Japan, they try to thrive on doing whatever work they can get their hands on. However, Shinpachi and Kagura still havent been paid... Does Gin-chan really spend all that cash playing pachinko?Meanwhile, when Gintoki drunkenly staggers home one night, an alien spaceship crashes nearby. A fatally injured crew member emerges from the ship and gives Gintoki a strange, clock-shaped device, warning him that it is incredibly powerful and must be safeguarded. Mistaking it for his alarm clock, Gintoki proceeds to smash the device the next morning and suddenly discovers that the world outside his apartment has come to a standstill. With Kagura and Shinpachi at his side, he sets off to get the device fixed; though, as usual, nothing is ever that simple for the Yorozuya team.Filled with tongue-in-cheek humor and moments of heartfelt emotion, Gintamas fourth season finds Gintoki and his friends facing both their most hilarious misadventures and most dangerous crises yet.'
# /var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_40329/829279206.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][0] = summary
#    anime_id                                               name  \
# 0     32281                                     Kimi no Na wa.
# 1      5114                   Fullmetal Alchemist: Brotherhood
# 2     28977                                           Gintama°
# 3      9253                                        Steins;Gate
# 4      9969                                      Gintama&#039;
# 5     32935  Haikyuu!!: Karasuno Koukou VS Shiratorizawa Ga...
# 6     11061                             Hunter x Hunter (2011)
# 7       820                               Ginga Eiyuu Densetsu
# 8     15335  Gintama Movie: Kanketsu-hen - Yorozuya yo Eien...
# 9     15417                           Gintama&#039;: Enchousen
#
#                                                genre   type episodes  rating  \
# 0               Drama, Romance, School, Supernatural  Movie        1    9.37
# 1  Action, Adventure, Drama, Fantasy, Magic, Mili...     TV       64    9.26
# 2  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.25
# 3                                   Sci-Fi, Thriller     TV       24    9.17
# 4  Action, Comedy, Historical, Parody, Samurai, S...     TV       51    9.16
# 5             Comedy, Drama, School, Shounen, Sports     TV       10    9.15
# 6            Action, Adventure, Shounen, Super Power     TV      148    9.13
# 7                     Drama, Military, Sci-Fi, Space    OVA      110    9.11
# 8  Action, Comedy, Historical, Parody, Samurai, S...  Movie        1    9.10
# 9  Action, Comedy, Historical, Parody, Samurai, S...     TV       13    9.11
#
#    members                                           synopsis
# 0   200630  Mitsuha Miyamizu, a high school girl, yearns t...
# 1   793665                                                  0
# 2   114262                                                  0
# 3   673572                                                  0
# 4   151266                                                  0
# 5    93351                                                  0
# 6   425855                                                  0
# 7    80679                                                  0
# 8    72534                                                  0
# 9    81109                                                  0

# %% [markdown]
# # Generate New Column for synopsis (Only run once)

# %%
# split dataframe into chunks
for i,chunk in enumerate(pd.read_csv('anime_plus.csv', chunksize=100)):
        chunk.to_csv(project_configs.dataset + 'anime_{}.csv'.format(i), index=False)
print("Number of files: {}".format(i))
# Out:
# Number of files: 122

# %% [markdown]
# # The main data wrangling

# %%
import parallel

l = []
for i in os.listdir('data/'):
    l.append(i)
for filename in l:
    check = parallel.checker(filename)
    if check:
        continue
    print("Generating summaries for the file: {}".format(filename) )
    df = pd.read_csv(project_configs.dataset+filename)
    df['anime_id'] = pd.Series(df['anime_id'], dtype="string")
    obj = synopsis_extractor()
    for i, anime in enumerate(tqdm(df['anime_id'])):
        synopsis = obj.synopsis_scrap(str(anime))
        df['synopsis'][i] = synopsis
    anime_w_synopsis = df[~df['synopsis'].isnull()]
    anime_w_synopsis.to_csv(project_configs.dataset2 +filename)
    print("Dataframe has been updated with synopsis")

    # doesnt add to lockfile until file has been completley finished. 
    parallel.checker(filename)
    print("{} has been locked.".format(filename))   
    anime_w_synopsis.head(10)
# Out:
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_37.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_23.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_22.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_36.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_122.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_108.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_120.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_20.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_34.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_35.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_21.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_121.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_109.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_119.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_19.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_25.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_31.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# .DS_Store already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_30.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_24.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_18.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_118.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_32.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_26.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_27.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_33.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_97.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_83.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_54.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_40.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_68.csv already exists in training set. Skipping...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_4.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:46<00:00,  1.06s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_4.csv already exists in training set. Skipping...
# True
# anime_4.csv has been locked.
#     Unnamed: 0 anime_id                                               name  \
# 0          400     9941                                  Tiger &amp; Bunny
# 1          401    14813  Yahari Ore no Seishun Love Comedy wa Machigatt...
# 3          403    21855                                     Hanamonogatari
# 5          405     2159                                 Ookiku Furikabutte
# 6          406    28297                                   Ore Monogatari!!
# 8          408     2154                                    Tekkon Kinkreet
# 10         410      861                                           xxxHOLiC
# 11         411     1689                              Byousoku 5 Centimeter
# 12         412    34103  Danganronpa 3: The End of Kibougamine Gakuen -...
# 13         413     3665         Ginga Eiyuu Densetsu Gaiden: Rasen Meikyuu
#
#                                                 genre     type  episodes  \
# 0                Action, Comedy, Mystery, Super Power       TV        25
# 1                      Comedy, Drama, Romance, School       TV        13
# 3                       Comedy, Mystery, Supernatural       TV         5
# 5                                      Comedy, Sports       TV        25
# 6                             Comedy, Romance, Shoujo       TV        24
# 8      Action, Adventure, Psychological, Supernatural    Movie         1
# 10  Comedy, Drama, Mystery, Psychological, Superna...       TV        24
# 11                      Drama, Romance, Slice of Life    Movie         3
# 12             Action, Horror, Mystery, Psychological  Special         1
# 13                     Drama, Military, Sci-Fi, Space      OVA        28
#
#     rating  members                                           synopsis
# 0     8.12   104075  In Stern Bild City, those with special abiliti...
# 1     8.12   353876  Hachiman Hikigaya is an apathetic high school ...
# 3     8.11   124886  Now that Koyomi Araragi and Hitagi Senjougahar...
# 5     8.11    49599  Ren Mihashi was the ace of his middle schools ...
# 6     8.11   200833  With his muscular build and tall stature, Take...
# 8     8.11    46018  The streets of Treasure Town are said to belon...
# 10    8.11   150872  Kimihiro Watanuki can see spirits and other as...
# 11    8.10   324035  What happens when two people love each other b...
# 12    8.10    29969  The Future Foundation is in shambles after the...
# 13    8.10     7712  Ginga Eiyuu Densetsu Gaiden (1999) is the seco...
# lock files: {'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_5.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:51<00:00,  1.11s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_5.csv already exists in training set. Skipping...
# True
# anime_5.csv has been locked.
#     Unnamed: 0 anime_id                                               name  \
# 0          500     2605                           Sayonara Zetsubou Sensei
# 4          504     6351  Clannad: After Story - Mou Hitotsu no Sekai, K...
# 6          506     3782         Kara no Kyoukai 2: Satsujin Kousatsu (Zen)
# 7          507     3572                                          Macross F
# 8          508     8310                                        Magic Kaito
# 9          509      114                        Sakigake!! Cromartie Koukou
# 11         511      658     Touhai Densetsu Akagi: Yami ni Maiorita Tensai
# 12         512    10012                                  Carnival Phantasm
# 13         513    32370                                  D.Gray-man Hallow
# 14         514    22961                            Date A Live: Encore OVA
#
#                                                 genre     type  episodes  \
# 0                              Comedy, Parody, School       TV        12
# 4                              Drama, Romance, School  Special         1
# 6    Action, Mystery, Romance, Supernatural, Thriller    Movie         1
# 7   Action, Mecha, Military, Music, Romance, Sci-F...       TV        25
# 8                 Adventure, Comedy, Romance, Shounen  Special        12
# 9                             Comedy, School, Shounen       TV        26
# 11              Game, Psychological, Seinen, Thriller       TV        26
# 12                       Comedy, Parody, Supernatural      OVA        12
# 13               Action, Demons, Shounen, Super Power       TV        13
# 14                             Romance, Slice of Life      OVA         1
#
#     rating  members                                           synopsis
# 0     8.03   174531  Nozomu Itoshiki is a high school teacher so pe...
# 4     8.02   138364  On a rainy day, Ryou Fujibayashi musters up th...
# 6     8.02   114415  In the winter of 1995, Mikiya Kokutou passes a...
# 7     8.02    95551  Following a catastrophic war against a race of...
# 8     8.02    27274  Magic is not real—everyone knows that. When pe...
# 9     8.02    67254  Takashi Kamiyama is your typical mild-mannered...
# 11    8.02    48127  While mahjong is a game that is often played w...
# 12    8.01    71976  The Carnival Moment is a time when several nar...
# 13    8.01    72499  Despite the recent Akuma attack, the members o...
# 14    8.01    48432  On the day of the Tanabata festival, Shidou It...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_69.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:51<00:00,  1.11s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_69.csv already exists in training set. Skipping...
# True
# anime_69.csv has been locked.
#     Unnamed: 0 anime_id                              name  \
# 14        6914    31300  Irodorimidori: Change Our Mirai!
# 16        6916    21421               Mahou Shoujo Taisen
# 31        6931    31157                      ClassicaLoid
# 58        6958    30920                             Utopa
# 64        6964    13309        Kyoto Animation: Hoshi-hen
# 75        6975    17513                   Diabolik Lovers
# 98        6998    32438                           Mayoiga
#
#                                     genre     type  episodes  rating  members  \
# 14                                  Music    Music         1    5.85      721
# 16                                  Magic       TV        26    5.85    12783
# 31                          Comedy, Music       TV        25    5.84    11717
# 58                                 Sci-Fi    Movie         1    5.83      590
# 64                                Fantasy  Special         1    5.82     2295
# 75         Harem, School, Shoujo, Vampire       TV        12    5.81   107960
# 98  Drama, Horror, Mystery, Psychological       TV        12    5.80   117090
#
#                                              synopsis
# 14  The members of the band Irodorimidori—guitaris...
# 16  "Mahou Shoujo Taisen" is a project created fro...
# 31  Ever since her father used up the last of the ...
# 58  Hundreds of years after the 20th century, natu...
# 64  An incomplete storyboard rests on a desk. With...
# 75  At the behest of her father, Yui Komori goes t...
# 98  A bus full of eccentric individuals is headed ...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_41.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:52<00:00,  1.13s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_41.csv already exists in training set. Skipping...
# True
# anime_41.csv has been locked.
#     Unnamed: 0 anime_id                                   name  \
# 2         4102      373               Bannou Bunka Neko-Musume
# 14        4114      385                              Gilgamesh
# 15        4115    10470                     God Eater Prologue
# 33        4133    29697  Prince of Tennis: Message in a Bottle
# 36        4136    33524              Sakamoto desu ga? Special
# 53        4153    17731                      Ketsuekigata-kun!
# 77        4177    25397                           Absolute Duo
#
#                                                 genre     type  episodes  \
# 2            Adventure, Comedy, Mecha, Sci-Fi, Seinen      OVA         6
# 14               Drama, Fantasy, Sci-Fi, Supernatural       TV        26
# 15                  Action, Fantasy, Military, Sci-Fi  Special         1
# 33                    Comedy, School, Shounen, Sports  Special         1
# 36                             Comedy, School, Seinen  Special         1
# 53                                             Comedy       TV        12
# 77  Action, Ecchi, Harem, Romance, School, Superna...       TV        12
#
#     rating  members                                           synopsis
# 2     6.80     6122  Ryuunosuke Natsume is the son of genius invent...
# 14    6.80    25332  In an attempt to gather information on immorta...
# 15    6.80    19414  Driven to the verge of extinction by "Aragami,...
# 33    6.80      813  The Rikkai University-Affiliated Middle School...
# 36    6.80    23745  Sakamoto has it all: he is handsome, he excels...
# 53    6.79     6331  Are all A Types kind yet indecisive? Does bein...
# 77    6.78   168811  Individuals who can materialize weapons from t...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_55.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_55.csv already exists in training set. Skipping...
# True
# anime_55.csv has been locked.
#     Unnamed: 0 anime_id                                           name  \
# 0         5500    32881                                   Tiger Mask W
# 2         5502    26443                                       Triage X
# 8         5508    12967                                Arcana Famiglia
# 25        5525     7598                                   Loups=Garous
# 38        5538    33056                                      Buddy Go!
# 59        5559    19257                                      Meganebu!
# 66        5566    31540                                    Sekkou Boys
# 69        5569    33668                           Soushin Shoujo Matoi
# 72        5572     8449                                 Togainu no Chi
# 85        5585     3015  Ginga Eiyuu Densetsu Gaiden: Ougon no Tsubasa
#
#                                               genre     type episodes  rating  \
# 0                    Action, Drama, Shounen, Sports       TV  Unknown    6.44
# 2                 Action, Adventure, Ecchi, Shounen       TV       10    6.44
# 8                    Action, Harem, Romance, Shoujo       TV       12    6.43
# 25                        Mystery, Sci-Fi, Thriller    Movie        1    6.43
# 38                          Comedy, Romance, Shoujo  Special        3    6.42
# 59                    Comedy, School, Slice of Life       TV       12    6.42
# 66                                    Comedy, Music       TV       12    6.42
# 69                              Magic, Supernatural       TV       12    6.42
# 72                       Action, Sci-Fi, Shounen Ai       TV       12    6.42
# 85  Action, Drama, Military, Sci-Fi, Shounen, Space    Movie        1    6.41
#
#     members                                           synopsis
# 0      8652  Two young wrestlers face each other in a recen...
# 2     59632  In a deadly terrorist attack, Arashi Mikami na...
# 8    106391  ​On the island of Regalo, a group of supernatu...
# 25    12350  In a future governed through the lens of a cam...
# 38     1415  Shizuku Ishiai uses dance as a form of self-ex...
# 59    22411  At Himaraya Third Technical School, five bespe...
# 66    28303  As luck would have it, on her first day at Hol...
# 69    12549  Matoi Sumeragi wishes for nothing more than to...
# 72    53377  In the wake of a third world war which left Ja...
# 85     6579  The Galactic Empire and the Free Planets Allia...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_82.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:48<00:00,  1.08s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_82.csv already exists in training set. Skipping...
# True
# anime_82.csv has been locked.
#     Unnamed: 0 anime_id                                          name  \
# 0         8200    33566                                          Baki
# 25        8225    33712                           Bikini Warriors OVA
# 98        8298    33728  Chain Chronicle: Haecceitas no Hikari Part 1
#
#                                          genre   type episodes  rating  \
# 0                Action, Martial Arts, Shounen    OVA  Unknown    8.27
# 25              Comedy, Ecchi, Fantasy, Parody    OVA        2    5.33
# 98  Action, Adventure, Fantasy, Magic, Shounen  Movie        1    6.67
#
#     members                                           synopsis
# 0      1448  As if bound by fate, five of the world’s most ...
# 25     3404  New OVAs slated for release in Fall 2016. The ...
# 98     5589  Set in the land of Yuguto, the people thought ...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_96.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:34<00:00,  1.05it/s]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_96.csv already exists in training set. Skipping...
# True
# anime_96.csv has been locked.
# Empty DataFrame
# Columns: [Unnamed: 0, anime_id, name, genre, type, episodes, rating, members, synopsis]
# Index: []
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_80.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [02:06<00:00,  1.26s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_80.csv already exists in training set. Skipping...
# True
# anime_80.csv has been locked.
#     Unnamed: 0 anime_id                                       name  \
# 7         8007    29978                                        001
# 9         8009     1657  Byston Well Monogatari: Garzey no Tsubasa
# 12        8012     2776                        Generation of Chaos
# 13        8013    16436                             Tenshi no Drop
# 14        8014    33394                  Mahou Shoujo? Naria☆Girls
# 16        8016    22377                                Wonder Momo
# 17        8017    29979                              Petting a Dog
# 21        8021    16606                                   C.L.A.Y.
# 24        8024    19315                                       Pupa
# 29        8029    16602                          Dead Girl Trailer
#
#                                         genre     type  episodes  rating  \
# 7                                      Comedy      ONA         1    4.00
# 9                                     Fantasy      OVA         3    3.99
# 12  Action, Adventure, Demons, Fantasy, Magic      OVA         1    3.98
# 13          Comedy, Ecchi, Shoujo Ai, Shounen  Special         1    3.96
# 14                                      Magic       TV        12    3.91
# 16         Action, Game, Martial Arts, School      ONA         5    3.90
# 17                              Slice of Life      ONA         1    3.88
# 21                                     Horror      ONA         1    3.84
# 24             Fantasy, Horror, Psychological       TV        12    3.82
# 29     Horror, Parody, Supernatural, Thriller      ONA         1    3.74
#
#     members                                           synopsis
# 7       916  Amid a flurry of rain, a windshield wiper rema...
# 9      5822  Christopher "Chris" Chiaki is an easygoing guy...
# 12     1010  In the world of Neverland, humans and monsters...
# 13     6308  Botan Ichiges lifelong dream is to enjoy a tea...
# 14     3414  After the Ice Queen brings eternal winter to t...
# 16     3218  One day, a group of aliens planning to take ov...
# 17      375        A man and his dog share an intimate moment.
# 21     1104  In a gray and empty landscape, a spherical, ye...
# 24    83652  Abandoned by their abusive parents and with on...
# 29      910  Once upon a time, a girl was brutally murdered...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# Generating summaries for the file: anime_94.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:38<00:00,  1.01it/s]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_94.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv'}
# anime_94.csv already exists in training set. Skipping...
# True
# anime_94.csv has been locked.
# Empty DataFrame
# Columns: [Unnamed: 0, anime_id, name, genre, type, episodes, rating, members, synopsis]
# Index: []
# ...
# 2     7.88   534657  In class 3-3 of Yomiyama North Junior High, tr...
# 4     7.88   105183  As the grand festival of True Cross Academy dr...
# 5     7.88   152811  The year is 320. Under the rule of the bellige...
# 6     7.88   117091  Ichiko Sakura lives life on easy mode. Blessed...
# 7     7.88    14414  Kuroo Hazama, also known as "Black Jack," is a...
# 8     7.88   336349  Life in the bustling city of Orario is never d...
# 9     7.88    22774  One night, Mikado Ryuugamine accepts an invita...
# 11    7.88    70787  It is almost the end of the year, and Houkago ...
# 13    7.88   359011  Mirai Kuriyama is the sole survivor of a clan ...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_7.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_57.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_94.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv', 'anime_43.csv'}
# Generating summaries for the file: anime_6.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
# 100%|██████████| 100/100 [01:58<00:00,  1.18s/it]
# Dataframe has been updated with synopsis
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_7.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_6.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_57.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_94.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv', 'anime_43.csv'}
# anime_6.csv already exists in training set. Skipping...
# True
# anime_6.csv has been locked.
#     Unnamed: 0 anime_id                                               name  \
# 0          600    12445                           Tasogare Otome x Amnesia
# 2          602    23225                            Yuru Yuri Nachuyachumi!
# 4          604    12893              Danshi Koukousei no Nichijou Specials
# 5          605     1505  Detective Conan Movie 09: Strategy Above the D...
# 8          608    22265                              Free!: Eternal Summer
# 9          609    13117                      Hakuouki Movie 1: Kyoto Ranbu
# 11         611    16904                                   K: Missing Kings
# 12         612       97                                         Last Exile
# 14         614     2273       Mobile Suit Gundam Wing: Endless Waltz Movie
# 15         615     1735                                 Naruto: Shippuuden
#
#                                                 genre     type episodes  \
# 0   Horror, Mystery, Romance, School, Shounen, Sup...       TV       12
# 2                    Comedy, Shoujo Ai, Slice of Life      OVA        1
# 4              Comedy, School, Shounen, Slice of Life  Special        6
# 5         Adventure, Comedy, Mystery, Police, Shounen    Movie        1
# 8               Comedy, School, Slice of Life, Sports       TV       13
# 9   Action, Drama, Historical, Josei, Samurai, Sup...    Movie        1
# 11                  Action, Super Power, Supernatural    Movie        1
# 12                          Action, Adventure, Sci-Fi       TV       26
# 14      Action, Drama, Mecha, Military, Sci-Fi, Space    Movie        1
# 15  Action, Comedy, Martial Arts, Shounen, Super P...       TV  Unknown
#
#     rating  members                                           synopsis
# 0     7.95   172367  Seikyou Private Academy, built on the intrigue...
# 2     7.95    28339  Even during summer break, the Amusement Club l...
# 4     7.94    49891  The original gag comedy manga follows the humo...
# 5     7.94    20347  Fifteen years ago in a barren stretch of the P...
# 8     7.94   150596  Even though it has been a year since the Iwato...
# 9     7.94    12076  Disguised as a boy, young Chizuru Yukimura lea...
# 11    7.94    98549  Its been a year since the disappearance of Shi...
# 12    7.94   104193  In the world of Prester, flight is the dominan...
# 14    7.94    35711  It is A.C. 196—one year after the conflict bet...
# 15    7.94   533578  It has been two and a half years since Naruto ...
# lock files: {'anime_5.csv', 'anime_35.csv', 'anime_69.csv', 'anime_122.csv', 'anime_80.csv', 'anime_41.csv', 'anime_31.csv', 'anime_54.csv', 'anime_55.csv', '.DS_Store', 'anime_40.csv', 'anime_22.csv', 'anime_33.csv', 'anime_7.csv', 'anime_109.csv', 'anime_23.csv', 'anime_120.csv', 'anime_30.csv', 'anime_37.csv', 'anime_18.csv', 'anime_20.csv', 'anime_34.csv', 'anime_118.csv', 'anime_108.csv', 'anime_25.csv', 'anime_6.csv', 'anime_68.csv', 'anime_19.csv', 'anime_26.csv', 'anime_57.csv', 'anime_27.csv', 'anime_97.csv', 'anime_24.csv', 'anime_121.csv', 'anime_119.csv', 'anime_96.csv', 'anime_36.csv', 'anime_82.csv', 'anime_83.csv', 'anime_94.csv', 'anime_4.csv', 'anime_32.csv', 'anime_21.csv', 'anime_43.csv'}
# Generating summaries for the file: anime_56.csv
#   0%|          | 0/100 [00:00<?, ?it/s]/var/folders/q3/z0pdr58n4bn46rs6tvs5t1y00000gn/T/ipykernel_41320/3284464407.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['synopsis'][i] = synopsis
#  20%|██        | 20/100 [00:23<01:34,  1.19s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/simonlee/Anime-recommendations/anime_pipeline.ipynb Cell 16 in <cell line: 6>()
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> obj = synopsis_extractor()
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> for i, anime in enumerate(tqdm(df['anime_id'])):
# ---> <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a>     synopsis = obj.synopsis_scrap(str(anime))
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a>     df['synopsis'][i] = synopsis
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> anime_w_synopsis = df[~df['synopsis'].isnull()]
#
# /Users/simonlee/Anime-recommendations/anime_pipeline.ipynb Cell 16 in synopsis_extractor.synopsis_scrap(self, anime_id)
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=12'>13</a> '''
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=13'>14</a> extracts the synopsis portion via keyword 'MAL' and 'Rewrite' and removes all useless crap and returns summary
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=14'>15</a> '''
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=15'>16</a> deletions = ['[Written by MAL Rewrite]', 'by MAL_Articles', '\n', '\r', '\'']
# ---> <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=16'>17</a> htmldata = self.getdata("https://myanimelist.net/anime/" + anime_id)
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=17'>18</a> soup = BeautifulSoup(htmldata, 'html.parser')
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=18'>19</a> data = ''
#
# /Users/simonlee/Anime-recommendations/anime_pipeline.ipynb Cell 16 in synopsis_extractor.getdata(self, url)
#       <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=4'>5</a> def getdata(self, url):
#       <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=5'>6</a>     '''
#       <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=6'>7</a>     link for extract html data
#       <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=7'>8</a>     '''
# ----> <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=8'>9</a>     r = requests.get(url)
#      <a href='vscode-notebook-cell:/Users/simonlee/Anime-recommendations/anime_pipeline.ipynb#X15sZmlsZQ%3D%3D?line=9'>10</a>     return r.text
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/requests/adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     438 try:
#     439     if not chunked:
# --> 440         resp = conn.urlopen(
#     441             method=request.method,
#     442             url=url,
#     443             body=request.body,
#     444             headers=request.headers,
#     445             redirect=False,
#     446             assert_same_host=False,
#     447             preload_content=False,
#     448             decode_content=False,
#     449             retries=self.max_retries,
#     450             timeout=timeout
#     451         )
#     453     # Send the request.
#     454     else:
#     455         if hasattr(conn, 'proxy_pool'):
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     444             httplib_response = conn.getresponse()
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     451     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/urllib3/connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     441 except TypeError:
#     442     # Python 3
#     443     try:
# --> 444         httplib_response = conn.getresponse()
#     445     except BaseException as e:
#     446         # Remove the TypeError from the exception chain in
#     447         # Python 3 (including for exceptions like SystemExit).
#     448         # Otherwise it looks like a bug in the code.
#     449         six.raise_from(e, None)
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:1377, in HTTPConnection.getresponse(self)
#    1375 try:
#    1376     try:
# -> 1377         response.begin()
#    1378     except ConnectionError:
#    1379         self.close()
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:320, in HTTPResponse.begin(self)
#     318 # read until we get a non-100 response
#     319 while True:
# --> 320     version, status, reason = self._read_status()
#     321     if status != CONTINUE:
#     322         break
#
# File ~/opt/anaconda3/lib/python3.9/http/client.py:281, in HTTPResponse._read_status(self)
#     280 def _read_status(self):
# --> 281     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     282     if len(line) > _MAXLINE:
#     283         raise LineTooLong("status line")
#
# File ~/opt/anaconda3/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1237     if flags != 0:
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#    1243     return super().recv_into(buffer, nbytes, flags)
#
# File ~/opt/anaconda3/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1097 try:
#    1098     if buffer is not None:
# -> 1099         return self._sslobj.read(len, buffer)
#    1100     else:
#    1101         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# setting the path for joining multiple files
files = os.path.join(project_configs.dataset2, "anime_*.csv")

# list of merged files returned
files = glob.glob(files)

print("Resultant CSV after joining all CSV files at a particular location...");

# joining files with concat and read_csv
df = pd.concat(map(pd.read_csv, files), ignore_index=True)
print(df)

# %%
# delete all unnamed: # columns
# optional cell

del df['Unnamed: 0.3']
del df['Unnamed: 0.2']
del df['Unnamed: 0.1']

# %% [markdown]
# # TODO: Delete members column then try to run through writing out synopsis's for all 14,000 anime. If successful save into new csv file

# %% [markdown]
# # TODO: Download BERT NLP model
#
# ``` pip install -U sentence-transformers ```

# %% [markdown]
# # TODO: Run Principal component analysis for a nice graph

# %% [markdown]
# # TODO: use cosine similarity function which is the foundation of the recommendation system

# %% [markdown]
# # TODO: find some cool ways to visualize our results

# %% [markdown]
# # TODO: Apply our work to other datasets?
